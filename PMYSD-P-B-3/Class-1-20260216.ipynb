# %% [markdown]
# <a href="https://colab.research.google.com/github/NaqashZulfiqar/Python-Learning/blob/main/PMYSD-PB-3/Class-1-20260216.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10

# %%
print(x)
# Out:
# 10

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
a=10
b=10.5
c="Machine Learning"
d=True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(x)
# Out:
# 10

# %%
del x

# %%
x = 2+3j

# %%
print(x)
# Out:
# (2+3j)

# %%
print(type(x))
# Out:
# <class 'complex'>

# %% [markdown]
# Data **Types**

# %%
i = 10
j = [1,2,3,4]
k = {1,2,3,4}
l = (2,4)
print(type(i))
print(type(j))
print(type(k))
print(type(l))
# Out:
# <class 'int'>
# <class 'list'>
# <class 'set'>
# <class 'tuple'>
