# %% [markdown]
# <a href="https://colab.research.google.com/github/NaqashZulfiqar/Python-Learning/blob/main/SirZafarIqbal/Lecture-01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Yes! I can learn python.")
# Out:
# Yes! I can learn python.

# %%
print("testing")
print(123)
# Out:
# testing
# 123

# %%
3
# Out:
# 3

# %%
3+4
# Out:
# 7

# %%
"Naqash"
# Out:
# 'Naqash'
