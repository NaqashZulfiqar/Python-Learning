# %% [markdown]
# <a href="https://colab.research.google.com/github/NaqashZulfiqar/Python-Learning/blob/main/SirZafarIqbal/Lecture-04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Variables**

# %%
id=1234
name='Smith'
phone=123-456-7890
email='abc@gmail.com'
print(1234)
# Out:
# 1234

# %%
print(id)
# Out:
# 1234

# %%
print(name)
# Out:
# Smith

# %% [markdown]
# **Arithmetic**

# %%
x=5
y=10
add = x + y
print(add)
# Out:
# 15

# %% [markdown]
# Variable **Rules**

# %%
_x=45

# %%
print(_x)
# Out:
# 45

# %%
8x=45
# Out:
#   File "/tmp/ipython-input-580750149.py", line 1
#     8x=45
#     ^
# SyntaxError: invalid decimal literal

# %%
x=56

# %%
print(x)
# Out:
# 56

# %%
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2644917711.py in <cell line: 0>()
# ----> 1 print(Name)
#
# NameError: name 'Name' is not defined

# %%
print(name)
# Out:
# Smith

# %%
print(NAME)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1048088141.py in <cell line: 0>()
# ----> 1 print(NAME)
#
# NameError: name 'NAME' is not defined

# %%
name='John'

# %%
input('Please enter your name?')
# Out:
# Please enter your name?Naqash
# 'Naqash'

# %%
name=input()
# Out:
# patrick

# %%
print(name)
# Out:
# patrick

# %%
name= 'Naqash ' + 'Zulfiqar'

# %%
name
# Out:
# 'Naqash Zulfiqar'

# %%
name='Python' + 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-404346782.py in <cell line: 0>()
# ----> 1 name='Python' + 7
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **Arrays**

# %%
name= 'Python'

# %%
# Python
# 012345
name[0]
# Out:
# 'P'

# %%
name[3]
# Out:
# 'h'

# %%
name[5]
# Out:
# 'n'

# %%
name[-1]
# Out:
# 'n'
