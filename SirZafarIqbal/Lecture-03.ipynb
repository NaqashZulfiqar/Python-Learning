# %% [markdown]
# <a href="https://colab.research.google.com/github/NaqashZulfiqar/Python-Learning/blob/main/SirZafarIqbal/Lecture-03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Basic of Python
print("Hello Python") #this is commneted
print('Hello')
# Out:
# Hello Python
# Hello

# %%
"Naqash"
# Out:
# 'Naqash'

# %%
print("He said,'Yes i can do it' ")
# Out:
# He said,'Yes i can do it'

# %%
print('He said,"Yes I Can do it" ')
# Out:
# He said,"Yes I Can do it"

# %%
print(r"C:\User\NewFolder")
# Out:
# C:\User\NewFolder

# %%
"Python"
# Out:
# 'Python'

# %% [markdown]
# **Arithmetic operation**

# %%
print("Addition:" , 5+3)
# Out:
# Addition: 8

# %%
print("Subtration : ", 5-3)
print("Multiplication : ", 5*3)
print("Division : ", 5/2)
print("Floor Division :", 5//2)
print("Modulus : ", 5%2)
print("Expontiation: ", 3**2)
print("Expontiation: ", 3**3)
# Out:
# Subtration :  2
# Multiplication :  15
# Division :  2.5
# Floor Division : 2
# Modulus :  1
# Expontiation:  9
# Expontiation:  27

# %%
5+4-3
# Out:
# 6

# %%
5+4-1
# Out:
# 8
